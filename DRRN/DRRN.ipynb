# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd "gdrive/My Drive/thesis"
# Out:
# /content/gdrive/My Drive/thesis

# %%
# !git clone https://github.com/Lornatang/DRRN-PyTorch
# Out:
# fatal: destination path 'DRRN-PyTorch' already exists and is not an empty directory.

# %%
# %cd "DRRN-PyTorch"
# Out:
# /content/gdrive/My Drive/thesis/DRRN-PyTorch

# %%
#!python train.py

# %%
# !python validate.py
# Out:
# Build DRRN model successfully.
# Load DRRN model weights `/content/gdrive/MyDrive/thesis/DRRN-PyTorch/results/DRRN_B1U9/best.pth.tar` successfully.
# Processing `/content/gdrive/MyDrive/thesis/DRRN-PyTorch/data/image_data/lr2/1020.jpg`...
# Processing `/content/gdrive/MyDrive/thesis/DRRN-PyTorch/data/image_data/lr2/1235.jpg`...
# Processing `/content/gdrive/MyDrive/thesis/DRRN-PyTorch/data/image_data/lr2/1254.jpg`...
# PSNR: 28.75dB.
